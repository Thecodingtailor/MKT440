# %%
import seaborn as sns
import pandas as pd
url ="https://raw.githubusercontent.com/chiharuishida/Tutorialdata/main/ad_dataset_withheaders.csv"
pd.read_csv(url)
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 0        68.95   35     256.09  Female         No
# 1        80.23   31     193.77    Male         No
# 2        69.47   26     236.50  Female         No
# 3        74.15   29     245.89    Male         No
# 4        68.37   35     225.58  Female         No
# ..         ...  ...        ...     ...        ...
# 995      72.97   30     208.58    Male        Yes
# 996      51.30   45     134.42    Male        Yes
# 997      51.63   51     120.37    Male        Yes
# 998      55.55   19     187.95  Female         No
# 999      45.01   26     178.35  Female        Yes
#
# [1000 rows x 5 columns]

# %%
Lion=pd.read_csv(url)

# %%
Lion.head(10)
# Out:
#    Site_Time  Age  DailyTime  Gender AdClicking
# 0      68.95   35     256.09  Female         No
# 1      80.23   31     193.77    Male         No
# 2      69.47   26     236.50  Female         No
# 3      74.15   29     245.89    Male         No
# 4      68.37   35     225.58  Female         No
# 5      59.99   23     226.74    Male         No
# 6      88.91   33     208.36  Female         No
# 7      66.00   48     131.76    Male        Yes
# 8      74.53   30     221.51    Male         No
# 9      69.88   20     183.82    Male         No

# %%
Lion.describe()
# Out:
#          Site_Time          Age    DailyTime
# count  1000.000000  1000.000000  1000.000000
# mean     65.000200    36.009000   180.000100
# std      15.853615     8.785562    43.902339
# min      32.600000    19.000000   104.780000
# 25%      51.360000    29.000000   138.830000
# 50%      68.215000    35.000000   183.130000
# 75%      78.547500    42.000000   218.792500
# max      91.430000    61.000000   269.960000

# %%
Lion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Site_Time   1000 non-null   float64
#  1   Age         1000 non-null   int64
#  2   DailyTime   1000 non-null   float64
#  3   Gender      1000 non-null   object
#  4   AdClicking  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
Lion['Age'].value_counts()
# Out:
# 31    60
# 36    50
# 28    48
# 29    48
# 33    43
# 35    39
# 30    39
# 34    39
# 32    38
# 26    37
# 38    37
# 37    36
# 40    36
# 27    33
# 41    32
# 45    30
# 39    30
# 25    27
# 42    26
# 43    23
# 44    21
# 24    21
# 50    20
# 23    19
# 46    18
# 49    18
# 48    16
# 52    15
# 47    13
# 22    13
# 51    12
# 53    10
# 54     9
# 55     7
# 20     6
# 21     6
# 57     6
# 19     6
# 60     4
# 58     4
# 56     2
# 59     2
# 61     1
# Name: Age, dtype: int64

# %%
Lion.corr()
# Out:
# <ipython-input-7-d6e4dbcbf3a2>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Lion.corr()
#            Site_Time       Age  DailyTime
# Site_Time   1.000000 -0.331513   0.518658
# Age        -0.331513  1.000000  -0.367209
# DailyTime   0.518658 -0.367209   1.000000

# %%
sns.heatmap(Lion.corr(), annot=True)
# Out:
# <ipython-input-8-b9c4385e94fe>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Lion.corr(), annot=True)
# <Axes: >

# %%
sns.heatmap(Lion.corr(), cmap="YlGnBu")
# Out:
# <ipython-input-9-a81961b68434>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Lion.corr(), cmap="YlGnBu")
# <Axes: >

# %%
sns.pairplot(Lion)

# %%
sns.scatterplot(x="Age", y="DailyTime", data=Lion)
# Out:
# <Axes: xlabel='Age', ylabel='DailyTime'>

# %%
sns.lmplot(x = "Age", y = "DailyTime", data = Lion)

# %%
sns.scatterplot(x="Age", y="DailyTime", hue="Site_Time", data=Lion)
# Out:
# <Axes: xlabel='Age', ylabel='DailyTime'>

# %%
sns.lmplot(x="Age", y="DailyTime", hue="Gender", data=Lion)

# %%
sns.countplot(x='Age', data=Lion)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Age', data=Lion, color='b')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
Lion_Age=Lion.groupby("Age")
Lion_Age.mean()
# Out:
# <ipython-input-17-caf13aecd9fc>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Lion_Age.mean()
#      Site_Time   DailyTime
# Age
# 19   60.966667  187.820000
# 20   66.708333  194.998333
# 21   68.460000  208.235000
# 22   71.010000  198.119231
# 23   68.333158  184.036842
# 24   71.245714  193.309048
# 25   71.360741  202.028519
# 26   69.430000  199.007027
# 27   71.093333  198.642727
# 28   69.783542  200.978542
# 29   68.904583  191.312500
# 30   70.937692  190.367949
# 31   71.065333  204.254167
# 32   72.170526  198.469211
# 33   68.890930  196.640465
# 34   70.092051  185.864103
# 35   67.401282  184.095128
# 36   66.815600  181.026000
# 37   67.152500  179.293611
# 38   59.214324  165.345135
# 39   61.964667  176.696000
# 40   64.083611  172.979167
# 41   60.256875  168.488125
# ...

# %%
sns.boxplot(x="Age", y="Gender", data=Lion)
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
sns.boxplot(x="Age", y="Gender", hue="DailyTime", data=Lion)
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
Age_top3_Age = Lion.nlargest(3,"Age")
Age_top3_Age
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 671      66.08   61     184.23    Male        Yes
# 110      66.63   60     176.98  Female        Yes
# 182      62.95   60     157.04  Female        Yes
